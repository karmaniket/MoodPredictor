# %%
import pandas as pd

# %%
data = {
    'text': [
        # Happy
        "having a great day", "this is wonderful", "love how things are going",
        "feeling pretty good today", "doing amazing", "beautiful weather today", "got so much accomplished", 
        "haha that was hilarious", "finally some good news", "everything's going perfectly",
        
        # Sad
        "feeling kinda down today", "life's hard sometimes", "miss the old days", 
        "everything feels empty", "not having a good day", "tried hard but didn't work out", "feeling low", 
        "feel left out", "nothing matters", "no one cares", "just me and my thoughts",
        "wish someone was here", "feel alone even with people", "need someone to talk to", 
        "isolated from everyone", "disconnected from the world",
        
        # Angry
        "this is making me so mad", "I'm really angry about this", "driving me crazy",
        "they totally screwed up", "I'm not cool with this", "that was so dumb", 
        "I'm done with them", "stop wasting my time", "about to lose it", "this is ridiculous",
        
        # Excited
        "I can do this all day", "this is amazing", "I can't wait", "this is gonna be amazing",
        "this is awesome", "onepiece is real", "this is incredible", "I'm so hyped", 
        "I'm so excited", "this is beyond exciting", "this is the best thing ever", "dream come true",
        
        # Calm
        "feeling pretty relaxed", "everything's peaceful", "so calm right now",
        "taking it easy today", "no rush today", "feeling centered", 
        "got everything under control", "enjoying the quiet", "just going with the flow", "feeling balanced",
        
        # Depressed
        "feeling really down", "everything feels hopeless", "done with life",
        "don't see the point", "feels meaningless", "drowning in sadness", 
        "I can't do this anymore", "feel empty inside", "everything is falling apart", "lost in darkness",
        
        # Furious
        "I'm so furious right now", "can't believe this happened", "getting on my nerves",
        "I'm seeing red", "this is unacceptable", "don't mess with me", 
        "pushed me over the edge", "boiling with rage", "this is the last straw", "never been so angry",
        
        # Content
        "feeling pretty content", "life's good", "no complaints here",
        "everything's fine", "no drama today", "happy where I am", 
        "nothing special but good", "chill day", "got no complaints", "life's treating me well",
        
        # Frustrated
        "losing my patience", "why this isn't working", "same problem again", "why do I bother", 
        "this is so frustrating", "nothing's going right", "this is upsetting", "can't believe how frustrating this is", 
        "how things turned out is frustrating", "this is so annoying", "deeply frustrated by this",
        
        # Serious
        "we need to talk", "this isn't a joke", "want an honest answer",
        "don't take this lightly", "this matters to me", "let's not mess around", 
        "need you to focus", "this needs attention", "stakes are high", "gotta be professional",
        
        # Bored
        "nothing to do", "this class is so long", "bored out of my mind",
        "just scrolling mindlessly", "same thing every day", "everything's so dull", 
        "need some excitement", "this is putting me to sleep", "dying of boredom", "when will this end",
        
        # Tired
        "barely slept last night", "I'm exhausted", "need a nap right now",
        "I need rest so bad", "work drained me", "so sleepy", 
        "completely worn out", "no energy left", "I'm so tired", "tired of explaining",
        
        # Irritated
        "can you not", "that's so irritating", "why can't people listen",
        "this noise is killing me", "need some space", "seriously stop", 
        "getting under my skin", "this is so irritating", "everything's bothering me", "easily annoyed today",
        
        # Confused
        "what just happened", "I don't get it", "wait what's the point",
        "now I'm lost", "thought I understood but nope", "can someone explain again", 
        "this makes no sense", "I'm puzzled", "my brain's scrambled", "no idea what's going on",
        
        # Hopeful
        "things will get better", "new day new chance", "trying to stay positive",
        "trusting the process", "there's light ahead", "keeping the faith", 
        "tomorrow will be better", "believe in good outcomes", "things are looking up", "staying optimistic",
        
        # Stressed
        "it's killing me", "need a break badly", "can't think straight", "so much pressure", 
        "overwhelmed with everything", "at my breaking point", "need to decompress", "feeling worried", 
        "nervous about the test", "hands are shaking", "hope I don't mess up", "this is scary", 
        "hate public speaking", "not sure I'm ready", "what if it goes wrong", "feeling really nervous", 
        "can't stop thinking", "having second thoughts", "confidence is shaking", "this sucks",
        
        # Grateful
        "really appreciate today", "so lucky right now", "feeling blessed",
        "that meant a lot", "can't thank you enough", "grateful for small things", 
        "thankful for this chance", "life's been kind", "appreciate the support", "blessed beyond measure",
        
        # Neutral
        "hey", "what's the plan today", "let's grab coffee",
        "running a bit late", "stuck in traffic", "hello", 
        "let me know when you're free", "just another day", "nothing much happening", "how's your day"
    ],
    'mood': [
        # Happy
        "happy", "happy", "happy", "happy", "happy", "happy", "happy", "happy", "happy", "happy",
        
        # Sad 
        "sad", "sad", "sad", "sad", "sad", "sad", "sad", "sad", "sad", "sad",
        "sad", "sad", "sad", "sad", "sad", "sad",
        
        # Angry
        "angry", "angry", "angry", "angry", "angry", "angry", "angry", "angry", "angry", "angry",
        
        # Excited
        "excited", "excited", "excited", "excited", "excited", "excited", "excited", "excited", "excited", "excited",
        "excited", "excited",
        
        # Calm
        "calm", "calm", "calm", "calm", "calm", "calm", "calm", "calm", "calm", "calm",
        
        # Depressed
        "depressed", "depressed", "depressed", "depressed", "depressed", "depressed", "depressed", "depressed", "depressed", "depressed",
        
        # Furious
        "furious", "furious", "furious", "furious", "furious", "furious", "furious", "furious", "furious", "furious",
        
        # Content
        "content", "content", "content", "content", "content", "content", "content", "content", "content", "content",
        
        # Frustrated
        "frustrated", "frustrated", "frustrated", "frustrated", "frustrated", "frustrated", "frustrated", "frustrated", "frustrated", "frustrated",
        "frustrated",
        
        # Serious
        "serious", "serious", "serious", "serious", "serious", "serious", "serious", "serious", "serious", "serious",
        
        # Bored
        "bored", "bored", "bored", "bored", "bored", "bored", "bored", "bored", "bored", "bored",
        
        # Tired
        "tired", "tired", "tired", "tired", "tired", "tired", "tired", "tired", "tired", "tired",
        
        # Irritated
        "irritated", "irritated", "irritated", "irritated", "irritated", "irritated", "irritated", "irritated", "irritated", "irritated",
        
        # Confused
        "confused", "confused", "confused", "confused", "confused", "confused", "confused", "confused", "confused", "confused",
        
        # Hopeful
        "hopeful", "hopeful", "hopeful", "hopeful", "hopeful", "hopeful", "hopeful", "hopeful", "hopeful", "hopeful",
        
        # Stressed
        "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed",
        "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed", "stressed",
        
        # Grateful
        "grateful", "grateful", "grateful", "grateful", "grateful", "grateful", "grateful", "grateful", "grateful", "grateful",
        
        # Neutral
        "neutral", "neutral", "neutral", "neutral", "neutral", "neutral", "neutral", "neutral", "neutral", "neutral"
    ]
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('mood_dataset.csv', index=False)

# %%
print(f"Total entries: {len(df)}")
print(f"Mood distribution:")
print(df['mood'].value_counts().sort_index())
print(f"\nDataset shape: {df.shape}")
# Out:
# Total entries: 199
# Mood distribution:
# mood
# angry         10
# bored         10
# calm          10
# confused      10
# content       10
# depressed     10
# excited       12
# frustrated    11
# furious       10
# grateful      10
# happy         10
# hopeful       10
# irritated     10
# neutral       10
# sad           16
# serious       10
# stressed      20
# tired         10
# Name: count, dtype: int64
#
# Dataset shape: (199, 2)
